# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FoodBalance.csv' , encoding = 'latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.shape
# Out:
# (60943, 12)

# %%
df["Area"].nunique()
# Out:
# 49

# %%
sorted(df.groupby('Area')['Y2017'].sum())
# Out:
# [0.0,
#  0.0,
#  59.84,
#  442.3399999999999,
#  12662.630000000003,
#  14650.740000000002,
#  19102.77,
#  21267.959999999945,
#  22101.299999999974,
#  22729.909999999963,
#  23154.179999999968,
#  27979.63999999996,
#  29342.200000000004,
#  29874.889999999967,
#  29936.999999999993,
#  41181.68,
#  49841.88000000002,
#  51114.83,
#  54343.32999999999,
#  55311.33000000002,
#  71594.67999999993,
#  73663.68999999992,
#  75919.34000000008,
#  95681.14999999985,
#  98138.86999999979,
#  101855.06999999999,
#  103223.76999999989,
#  124167.20000000003,
#  124771.21999999999,
#  126707.57999999997,
#  131197.72999999986,
#  149928.32999999993,
#  156665.46000000002,
#  161407.97999999986,
#  181098.70999999993,
#  213950.3800000001,
#  224599.0100000001,
#  229159.57000000024,
#  232030.4300000001,
#  239931.91999999984,
#  264660.66000000015,
#  322616.85000000027,
#  325644.2700000009,
#  337599.06000000064,
#  388495.36000000004,
#  448683.76,
#  517590.5400000007,
# ...

# %%
#Checking number of rows and columns of the dataset.

len(df)
# Out:
# 60943

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']
pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
y[1][1]
# Out:
# 8

# %%
#Total num & % of 2014.
per = ((df['Y2014'].isnull().sum())/60943)*100
print(df['Y2014'].isnull().sum())
print(round(per,2))
# Out:
# 1589
# 2.61

# %%
m = df.groupby(['Element'])
m.sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
# highest sum of stock Variation.

m = df.groupby(['Element'])
m.first()
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2905
# Fat supply quantity (g/capita/day)              4  Algeria       2901
# Feed                                            4  Algeria       2905
# Food                                            4  Algeria       2905
# Food supply (kcal/capita/day)                   4  Algeria       2901
# Food supply quantity (kg/capita/yr)             4  Algeria       2905
# Import Quantity                                 4  Algeria       2905
# Losses                                          4  Algeria       2905
# Other uses (non-food)                           4  Algeria       2905
# Processing                                      4  Algeria       2905
# Production                                      4  Algeria       2905
# ...

# %%
# total Protein supply qunatity in Madagascar in 2015.
df['Y2015'].loc[(df['Area']=='Madagascar') & (df['Element']=='Protein supply quantity (g/capita/day)')].sum()
# Out:
# 173.04999999999998

# %%
array  = np.array([[94, 89, 63],

                   [93, 92, 48],

                   [92, 94, 56]])
array[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
#Total sum of wine produced in 2015 and 2018.
df[['Y2015','Y2018']].loc[(df['Item'] == 'Wine')].sum()
# Out:
# Y2015    4251.81
# Y2018    4039.32
# dtype: float64

# %%
#which year had the least correlation with Element Code. 
m = df.groupby(['Element Code'])
m.min()
# Out:
#               Area Code     Area  Item Code                 Item  \
# Element Code
# 511                   4  Algeria       2501           Population
# 645                   4  Algeria       2511    Alcohol, Non-Food
# 664                   4  Algeria       2511  Alcoholic Beverages
# 674                   4  Algeria       2511  Alcoholic Beverages
# 684                   4  Algeria       2511  Alcoholic Beverages
# 5072                  4  Algeria       2511    Alcohol, Non-Food
# 5123                  4  Algeria       2511  Alcoholic Beverages
# 5131                  4  Algeria       2511  Alcoholic Beverages
# 5142                  4  Algeria       2511    Alcohol, Non-Food
# 5154                  4  Algeria       2511    Alcohol, Non-Food
# 5170                  4  Algeria       2511    Alcohol, Non-Food
# 5171                  7   Angola       2511  Alcoholic Beverages
# 5301                  4  Algeria       2501    Alcohol, Non-Food
# ...

# %%
# Mean and standard deviation across the year 2017
df['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
#Type of Error
my_tuppy = (1,2,5,8)

my_tuppy[2]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-33b447bcf865> in <module>
#       2 my_tuppy = (1,2,5,8)
#       3
# ----> 4 my_tuppy[2]=6
#
# TypeError: 'tuple' object does not support item assignment
